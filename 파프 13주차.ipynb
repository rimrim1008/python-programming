# %% [markdown]
# 파프 13주차

# %%
# 기본적인 루크 윈도우의 생성
import tkinter as tk

# 주 프로그램부
root_win = tk.TK() # 기본 윈도우 객체 반환

# 화면 구성 및 이벤트 처리
## ...

root_win.mainloop() # 윈도우에서 다양한 이벤트 처리 시작을 지시시

# %%
# 제목을 갖는 기본 윈도우
import tkinter as tk

# 주 프로그램부 
root_win = tk.TK()
root_win.title('나의 첫 윈도우') # 제목 표시줄에 윈도우 제목 표시시

# 화면 구성 및 이벤트 처리
## ...

root_win.mainloop() # 윈도우에서 다양한 이벤트 처리 시작을 지시

# %%
# 일정한 크기로 설정된 기본 윈도우
import tkinter as tk

# 주 프로그램부 
root_win = tk.Tk()
root_win.title('나의 첫 윈도우') # 제목 표시줄에 윈도우 제목 표시
root_win.geometry('500x200-0+50') # 윈도우의 크기 및 위치 설정
# 화면 구성 및 이벤트 처리
## ...

root_win.mainloop() # 윈도우에서 다양한 이벤트 처리 시작을 지시

# %%
# 윈도우의 크기 고정
import tkinter as tk

# 주 프로그램부 
root_win = tk.Tk()
root_win.title('나의 첫 윈도우') # 제목 표시줄에 윈도우 제목 표시
root_win.geometry('500x200-0+50') # 윈도우의 크기 및 위치 설정
root_win.resizable(width=False, height=False)

# 화면 구성 및 이벤트 처리
## ...

root_win.mainloop() # 윈도우에서 다양한 이벤트 처리 시작을 지시

# %%
import tkinter as tk
from tkinter import ttk

# tkinter 위젯은 'tk.위젯이름'으로 사용
# ttk 위젯은 'ttk.위젯이름'으로 사용

# %%
# 위젯에 설정된 옵션값 확인
import tkinter as tk
from tkinter as ttk

def display_options(widget):
    config = widget.configure()
    for key, value in config.items():
        print(f'{key:15s}\t{value}')
        
widget = ttk.Label(Nene)
display_options(widget)

# %% [markdown]
# # 기본 위젯

# %%
# Label 위젯의 기본 사용 예
import tkinter as tk # tk라는 별명으로  tkinter 모듈 임포트
from tkinter import ttk # tkinter에서 ttk 모듈 임포트

# 사용자 정의 함수부
def buildGUI():
    text_label1 = ttk.Label(win, text='안녕하세요')
    text_label1.pack()

# 주 프로그램부
win = tk.Tk() # 기본 윈도우 객체 반환
win.title('라벨 위젯 예1')
buildGUI () # 화면 구성
win.mainloop() # 윈도우에서 다양한 이벤트 처리 시작을 지시

# %%
# Label 위젯의 옵션 설정 예
import tkinter as tk # tk라는 별명으로  tkinter 모듈 임포트
from tkinter import ttk # tkinter에서 ttk 모듈 임포트

# 사용자 정의 함수부
def buildGUI():
    text_label1 = ttk.Label(win, text='안녕하세요')
    text_label1.pack()

    text_label2 = ttk.Label(win)
    text_label2.configure(text='반가워요', foreground='white', background='red', font=('맑은 고딕', 20))

    text_label1.pack()
    text_label2.pack()

# 주 프로그램부
win = tk.Tk() # 기본 윈도우 객체 반환
win.title('라벨 위젯 예1')
buildGUI () # 화면 구성
win.mainloop() # 윈도우에서 다양한 이벤트 처리 시작을 지시

# %%
# 라벨 위젯의 기본 스타일 이름 확인하기
import tkinter as tk
from tkinter import ttk

w = ttk.Label(None)
print(w.winfo_class()) # Label 위젯의 기본 스타일 이름 출력
# Out:
# TLabel

# %%
# Label 위젯의 스타일 설정 예예
import tkinter as tk # tk라는 별명으로  tkinter 모듈 임포트
from tkinter import ttk # tkinter에서 ttk 모듈 임포트

# 사용자 정의 함수부
def buildGUI():
    s = ttk.Style()
    s.configure('WR.TLabel', # 스타일 객체 생성
                foreground = 'white', # 새 스타일 이름
                background='red', # 전경색을 흰색으로 설정
                font=('맑은 고딕', 20) # 글꼴을 설정
    ) #WR.TLabel 스타일 정의 끝

    text_label1 = ttk.Label(win, text='안녕하세요', style='WR.TLabel')

    text_label2 = ttk.Label(win)
    text_label2.configure(text='반가워요', style='WR.TLabel')

    text_label1.pack()
    text_label2.pack()

# 주 프로그램부
win = tk.Tk() # 기본 윈도우 객체 반환
win.title('라벨 위젯 예1')
buildGUI () # 화면 구성
win.mainloop() # 윈도우에서 다양한 이벤트 처리 시작을 지시

# %%
# 버튼 위젯의 사용 예
import tkinter as tk # tk라는 별명으로  tkinter 모듈 임포트
from tkinter import ttk # tkinter에서 ttk 모듈 임포트

# 사용자 정의 함수부
def buildGUI():
    global text_label # 이벤트 핸들러에서 접근 위해
    text_label = ttk.Label(win, text='안녕하세요')
    
    input_btn = ttk.Button(win, text='입력',
                           command=input_btn_handler)
    quit_btn = ttk.Button(win, text='종료',
                          command=win.destroy)
    
    text_label.pack()
    input_btn.pack()
    quit_btn.pack()
    
def input_btn_handler(): # 버튼 클릭에 대한 이벤트  핸들러 함수
    text_label.configure(text = '반가워요')

# 주 프로그램부
win = tk.Tk() # 기본 윈도우 객체 반환
win.title('라벨 위젯 예1')
buildGUI () # 화면 구성
win.mainloop() # 윈도우에서 다양한 이벤트 처리 시작을 지시

# %%
# 엔트리 위젯의 사용 예
import tkinter as tk # tk라는 별명으로  tkinter 모듈 임포트
from tkinter import ttk # tkinter에서 ttk 모듈 임포트

# 사용자 정의 함수부
def buildGUI():
    global text_label # 이벤트 핸들러에서 접근 위해
    text_label = ttk.Label(win, text='안녕하세요')
    
    global name # 이벤트 핸들러에서 접근 위해
    name = tk.StringVar() # 엔트리 위젯에서 문자열 저장 위해
    input_entry = ttk.Entry(win, textvariable=name)
    
    input_btn = ttk.Button(win, text='입력',
                           command=input_btn_handler)
    quit_btn = ttk.Button(win, text='종료',
                          command=win.destroy)
    
    text_label.pack()
    input_entry.pack()
    input_btn.pack()
    quit_btn.pack()
    
def input_btn_handler(): # 버튼 클릭에 대한 이벤트  핸들러 함수
    text_label.configure(text = '반가워요, ' + name.get())
    name.set('') # 작은 따옴표 두 개로 빈문자열을 인수로 지정

# 주 프로그램부
win = tk.Tk() # 기본 윈도우 객체 반환
win.title('라벨 위젯 예1')
buildGUI () # 화면 구성
win.mainloop() # 윈도우에서 다양한 이벤트 처리 시작을 지시

# %%
# 텍스트 위젯의 사용 예
import tkinter as tk # tk라는 별명으로  tkinter 모듈 임포트
from tkinter import ttk # tkinter에서 ttk 모듈 임포트

# 사용자 정의 함수부
def buildGUI():
    global text_area
    text_area = tk.Text(win,
                        width=30, height=5, wrap=tk.WORD)
    
    input_btn = ttk.Button(win, text='출력',
                           command=input_btn_handler)
    
    text_area.pack()
    input_btn.pack()
    
def input_btn_handler(): # 버튼 클릭에 대한 이벤트  핸들러 함수
    print(text_area.get(0.0, tk.END))
    text_area.delete(0.0, tk.END)

# 주 프로그램부
win = tk.Tk() # 기본 윈도우 객체 반환
win.title('라벨 위젯 예1')
buildGUI () # 화면 구성
win.mainloop() # 윈도우에서 다양한 이벤트 처리 시작을 지시

# %%
# 스크롤 텍스트 위젯의 사용 예
import tkinter as tk # tk라는 별명으로  tkinter 모듈 임포트
from tkinter import ttk # tkinter에서 ttk 모듈 임포트
from tkinter import scrolledtext

# 사용자 정의 함수부
def buildGUI():
    global text_area
    text_area = scrolledtext.ScrolledText(win,
                        width=30, height=5, wrap=tk.WORD)
    
    input_btn = ttk.Button(win, text='출력',
                           command=input_btn_handler)
    
    text_area.pack()
    input_btn.pack()
    
def input_btn_handler(): # 버튼 클릭에 대한 이벤트  핸들러 함수
    print(text_area.get(0.0, tk.END))
    text_area.delete(0.0, tk.END)

# 주 프로그램부
win = tk.Tk() # 기본 윈도우 객체 반환
win.title('라벨 위젯 예1')
buildGUI () # 화면 구성
win.mainloop() # 윈도우에서 다양한 이벤트 처리 시작을 지시

# %%
# 체크버튼 위젯의 사용 예
import tkinter as tk # tk라는 별명으로  tkinter 모듈 임포트
from tkinter import ttk # tkinter에서 ttk 모듈 임포트
from tkinter import messagebox

# 사용자 정의 함수부
def buildGUI():
    global text_area
    global check # 이벤트 핸들러에서 접근 위해
    check = tk.IntVar() # 체트 상태 저장 위해
    check_btn = ttk.Checkbutton(win, text='옵션을 선택하세요',
                                variable=check,
                                command=open_dialog_box)
    check_btn.pack()

def open_dialog_box():
    if check.get() == 1:
        messagebox.showinfo('확인', '옵션 선택')
    else:
        messagebox.showinfo('확인', '옵션 해제')
    
# 주 프로그램부
win = tk.Tk() # 기본 윈도우 객체 반환
win.title('라벨 위젯 예1')
buildGUI () # 화면 구성
win.mainloop() # 윈도우에서 다양한 이벤트 처리 시작을 지시

# %%
# 라디오버튼 위젯의 사용 예
import tkinter as tk
from tkinter import ttk

GENDERS = ['남성', '여성', '기타']
COLORS = ['red', 'yellow', 'purple']

# 사용자 정의 함수부
def buildGUI():
    text_label = ttk.Label(win, text='당신의 성별은? ')
    text_label.pack()
    
    global gender # 이벤트 핸들러에서 접근 위해
    gender = tk.IntVar() #체크 상태 저장 위해
    for i in range(3):
        radio_btn = ttk.Radiobutton(win,
                                    text=GENDERS[i],
                                    value=i,
                                    variable=gender,
                                    command=radio_btn_handler
        )
        radio_btn.pack()

    gender.set(-1) # 라디오 버튼 선택 지우기

def radio_btn_handler():
    choice = gender.get()
    win.configure(background=COLORS[choice])
    
# 주 프로그램부
win = tk.Tk() # 기본 윈도우 객체 반환
win.title('버튼 위젯 예')
buildGUI() # 화면 구성
win.mainloop() # 윈도우에서 다양한 이벤트 처리 시작을 지시

# %% [markdown]
# # 04) 위젯의 배치

# %%
# pack()을 이용한 위젯 배치치
import tkinter as tk
from tkinter import ttk

# 사용자 정의 함수부
def buildGUI():
    btn1 = ttk.Button(win, text='버튼1')
    btn2 = ttk.Button(win, text='버튼2')
    btn3 = ttk.Button(win, text='버튼3')
    btn4 = ttk.Button(win, text='버튼4')
    btn5 = ttk.Button(win, text='버튼5')

    btn1.pack() # btn1.pack(side=tk.TOP)과 동일일
    btn2.pack()
    btn3.pack()
    btn4.pack()
    btn5.pack()


# 주 프로그램부
win = tk.Tk() # 기본 윈도우 객체 반환
win.title('pack() 배치의 예')
win.geometry('300x200')
buildGUI() # 화면 구성
win.mainloop() # 윈도우에서 다양한 이벤트 처리 시작을 지시

# %%
# pack()에 side 키워드 인수를 지정한 예
import tkinter as tk
from tkinter import ttk


# 사용자 정의 함수부
def buildGUI():
    btn1 = ttk.Button(win, text='버튼1')
    btn2 = ttk.Button(win, text='버튼2')
    btn3 = ttk.Button(win, text='버튼3')
    btn4 = ttk.Button(win, text='버튼4')
    btn5 = ttk.Button(win, text='버튼5')

    btn1.pack(side=tk.BOTTOM)
    btn2.pack(side=tk.LEFT)
    btn3.pack(side=tk.RIGHT)
    btn4.pack()
    btn5.pack(side=tk.TOP)


# 주 프로그램부
win = tk.Tk() # 기본 윈도우 객체 반환
win.title('pack() 배치의 예')
win.geometry('300x200')
buildGUI() # 화면 구성
win.mainloop() # 윈도우에서 다양한 이벤트 처리 시작을 지시

# %%
# pack()으로 위젯의 여백 지정하기
import tkinter as tk
from tkinter import ttk

# 사용자 정의 함수부
def buildGUI():
    btn1 = ttk.Button(win, text='버튼1')
    btn2 = ttk.Button(win, text='버튼2')
    btn3 = ttk.Button(win, text='버튼3')
    btn4 = ttk.Button(win, text='버튼4')
    btn5 = ttk.Button(win, text='버튼5')

    btn1.pack()
    btn2.pack(ipadx=10, ipady=10)
    btn3.pack(ipadx=10, ipady=10)
    btn4.pack(fill=tk.X)
    btn5.pack(fill=tk.X, padx=10, pady=10, ipadx=10, ipady=10)


# 주 프로그램부
win = tk.Tk() # 기본 윈도우 객체 반환
win.title('pack() 배치의 예')
win.geometry('300x200')
buildGUI() # 화면 구성
win.mainloop() # 윈도우에서 다양한 이벤트 처리 시작을 지시

# %%
# grid()을 이용한 위젯 배치
import tkinter as tk
from tkinter import ttk

# 사용자 정의 함수부
def buildGUI():
    btn1 = ttk.Button(win, text='버튼1')
    btn2 = ttk.Button(win, text='버튼2')
    btn3 = ttk.Button(win, text='버튼3')
    btn4 = ttk.Button(win, text='버튼4')
    btn5 = ttk.Button(win, text='버튼5')

    btn1.grid(row=0, column=0)
    btn2.grid(row=0, column=1)
    btn3.grid(row=1, column=1)
    btn4.grid(row=1, column=2)
    btn5.grid(row=2, column=0)


# 주 프로그램부
win = tk.Tk() # 기본 윈도우 객체 반환
win.title('pack() 배치의 예')
win.geometry('300x200')
buildGUI() # 화면 구성
win.mainloop() # 윈도우에서 다양한 이벤트 처리 시작을 지시

# %%
# sticky 키워드 인수의 사용 예
import tkinter as tk
from tkinter import ttk

# 사용자 정의 함수부
def buildGUI():
    btn1 = ttk.Button(win, text='버튼1')
    btn2 = ttk.Button(win, text='매우 긴~~~ 너비와 높이를 갖는 \n버\n튼\n2')
    btn3 = ttk.Button(win, text='버튼3')
    btn4 = ttk.Button(win, text='버튼4')
    btn5 = ttk.Button(win, text='버튼5')

    btn1.grid(row=0, column=0, sticky='se')
    btn2.grid(row=0, column=1, columnspan=2)
    btn3.grid(row=1, column=1, sticky='w')
    btn4.grid(row=1, column=2)
    btn5.grid(row=2, column=0)


# 주 프로그램부
win = tk.Tk() # 기본 윈도우 객체 반환
win.title('sticky 키워드 인수의 사용 예')
win.geometry('300x200')
buildGUI() # 화면 구성
win.mainloop() # 윈도우에서 다양한 이벤트 처리 시작을 지시

# %%
# Frame을 이용한 배치
import tkinter as tk
from tkinter import ttk

# 사용자 정의 함수부
def buildGUI():
    btn1 = ttk.Button(win, text='버튼1')
    btn2 = ttk.Button(win, text='매우 긴~~~ 너비와 높이를 갖는 \n버\n튼\n2')
    btn_group = ttk.Frame(win)
    btn3 = ttk.Button(btn_group, text='버튼3')
    btn4 = ttk.Button(btn_group, text='버튼4')
    btn5 = ttk.Button(win, text='버튼5')

    btn1.grid(row=0, column=0, sticky='se')
    btn2.grid(row=0, column=1, columnspan=2)
    btn3.pack(side=tk.LEFT)
    btn4.pack(side=tk.LEFT)
    btn_group.grid(row=1, column=1, sticky='w')
    btn5.grid(row=2, column=0)


# 주 프로그램부
win = tk.Tk() # 기본 윈도우 객체 반환
win.title('sticky 키워드 인수의 사용 예')
win.geometry('300x200')
buildGUI() # 화면 구성
win.mainloop() # 윈도우에서 다양한 이벤트 처리 시작을 지시
